# %% [markdown]
# # Objective
#
# Explain:
#
# Testing DFT integration
#
# Verifying PySCF works inside project structure
#
# Establishing baseline energy

# %%
import sys
import numpy as np
import pandas as pd
from pyscf import gto, scf

print("Python:", sys.version)
# Out:
# Python: 3.12.12 | packaged by conda-forge | (main, Jan 26 2026, 23:51:32) [GCC 14.3.0]

# %%
xyz_path = "../../data/raw/formaldehyde.xyz"

with open(xyz_path) as f:
    geometry = f.read()

print(geometry)
# Out:
# 4
# Formaldehyde
# C  0.000000  0.000000  0.000000
# O  0.000000  0.000000  1.200000
# H  0.000000  0.950000 -0.600000
# H  0.000000 -0.950000 -0.600000
