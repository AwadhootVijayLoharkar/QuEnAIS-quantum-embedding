# %%
from pyscf import dmrgscf
print(dmrgscf.settings.BLOCKEXE)
# Out:
# /home/loharkar/QuEnAIS-quantum-embedding/quenais-env2/bin/block2main

# %%
from pyscf import gto
from asf.wrapper import find_from_mol

mol= gto.M(atom="H 0 0 0;h 0 0 2", basis="sto-3g")

result = find_from_mol(mol)
print(result)
# Out:
# --------------------------------------------------------------------------------
# Calculating UHF orbitals
# --------------------------------------------------------------------------------
#
# -> Initiating a UHF calculation.
# converged SCF energy = -0.783792654277353  <S^2> = -4.4408921e-16  2S+1 = 1
#
# WARN: Not enough eigenvectors (len(x0)=1, nroots=3)
#
# <class 'pyscf.scf.uhf.UHF'> wavefunction has an internal instability
# -> Restarting SCF due to instability of previous solution.
# -> Initiating SCF restart number 1.
# converged SCF energy = -0.937212833089364  <S^2> = 0.94586489  2S+1 = 2.1871122
#
# WARN: Not enough eigenvectors (len(x0)=1, nroots=3)
#
# <class 'pyscf.scf.uhf.UHF'> wavefunction is stable in the internal stability analysis
# -> The calculated SCF solution is converged and stable.
#
# --------------------------------------------------------------------------------
# Calculating MP2 natural orbitals
# ...

# %%
import os
ligand_resnames = set()
with open("/home/loharkar/QuEnAIS-quantum-embedding/data/raw/1HVR.pdb") as f :
    for line in f :
        if line.startswith("HEATM"):
            ligand_resnames.add(line[17:20].strip())

print(ligand_resnames)
# Out:
# set()
